# %% [raw]
# import sys, os
# sys.path.append(os.getcwd()[:-5])
# print(sys.path)

# %%
import numpy as np
import matplotlib.pyplot as plt
import myRegression as reg
from utils import plot, npmap, load_data

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
plt.rcParams["figure.figsize"] = 10, 8

# %% [markdown]
# # Dummy data set

# %%
x, y = load_data("ex0.txt")

# %%
plt.scatter(x[:, 1], y)

# %%
predict = reg.std_lin_regression(x, y)
print(predict.w)
# Out:
# [ 3.00774324  1.69532264]

# %%
xtest = np.stack([np.ones(100),np.linspace(0, 1, 100)], axis=1)
ypred = predict(xtest)
plt.scatter(x[:, 1], y)
plt.plot(xtest[:, 1], ypred, "k-")

# %%
np.corrcoef(y, predict(x))
# Out:
# array([[ 1.        ,  0.98647356],
#        [ 0.98647356,  1.        ]])

# %%
predict = reg.lw_lin_regression(x, y, reg.gaussian_kernel(0.2))

# %%
xtest = np.stack([np.ones(100),np.linspace(0, 1, 100)], axis=1)
ypred = npmap(predict, xtest)
plt.scatter(x[:, 1], y)
plt.plot(xtest[:, 1], ypred, "k-")
# Out:
# d (200, 2)
# d (200, 200)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-0ab984e2635b> in <module>()
#       1 xtest = np.stack([np.ones(100),np.linspace(0, 1, 100)], axis=1)
# ----> 2 ypred = npmap(predict, xtest)
#       3 plt.scatter(x[:, 1], y)
#       4 plt.plot(xtest[:, 1], ypred, "k-")
#
# /Users/Gonzalo/github/machinelearninginaction/utils.py in npmap(*args, **kwargs)
#      74
#      75 def npmap(*args, **kwargs):
# ---> 76     return np.array(lmap(*args, **kwargs))
#      77
#      78
#
# /Users/Gonzalo/github/machinelearninginaction/utils.py in lmap(*args, **kwargs)
#      66
#      67 def lmap(*args, **kwargs):
# ---> 68     return list(map(*args, **kwargs))
#      69
#      70
#
# /Users/Gonzalo/github/machinelearninginaction/Ch08/myRegression.py in predictor(y)
#      38     x = np.atleast_2d(x)
#      39     def predictor(y):
# ...
